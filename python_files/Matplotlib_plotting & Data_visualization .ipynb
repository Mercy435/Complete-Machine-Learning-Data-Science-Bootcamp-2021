# %% [markdown]
# # Matplotlib is a part of data analysis and experiment

# %% [markdown]
# ## built on numpy arrays and python
# ## integrates directly with pandas
# ## creates basic and advanced plots
# ## simple to use

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot()
#plt.show()
# Out:
# []

# %%
plt.plot();

# %%
plt.plot([1,2,3,4])

# %%
x=[1,2,3,4]
y=[11,22,33,34]
plt.plot(x,y)

# %%
#1st method
fig=plt.figure() #creates a figure
ax=fig.add_subplot() #adds some axes
plt.show()

# %%
#2nd method
fig=plt.figure()
ax=fig.add_axes([1,1,1,1])
ax.plot(x,y) #add some daata
type(fig), type(ax)
# Out:
# (matplotlib.figure.Figure, matplotlib.axes._axes.Axes)

# %%
#3rd method (recommended)
fig, ax =plt.subplots()
ax.plot(x,y);

# %% [markdown]
# <img src="4.2 matplotlib-anatomy-of-a-plot-with-code.png"/>

# %%
fig,ax=plt.subplots()
ax.plot(x, [50,100,200,250]);
type(fig), type(ax) #we have pyplot API and object oriented API,
#this uses the object oriemtes api, we have figure object, axes objects
# Out:
# (matplotlib.figure.Figure, matplotlib.axes._subplots.AxesSubplot)

# %% [markdown]
# # matplotlib example workflow

# %%
#1. import matplotlib and get it ready for plotting in jupyter
# %matplotlib inline
import matplotlib.pyplot as plt

#2. prepare data
x=[1,2,3,4]
y=[11,22,33,44]

#3.setup plot
fig, ax=plt.subplots(figsize=(10,10)) #(width, height)
#fig size is the dimension of u=your plot 

#4. plot data
ax.plot(x,y)

#5. customize plot
ax.set(title="Simple Plot",
        xlabel="x-axis",
        ylabel="y-axis")

#6. save and show
fig.savefig("./images/sampleplot.png")

# %% [markdown]
# ## Making figures with Numpy arrays
# we want
# * line plot
# * scatter plot
# * bar plot
# * histogram
# * subplots

# %%
#create data
x=np.linspace(0,10,100)
x[:10]
#Return evenly spaced numbers over a specified interval.
# Out:
# array([0.        , 0.1010101 , 0.2020202 , 0.3030303 , 0.4040404 ,
#        0.50505051, 0.60606061, 0.70707071, 0.80808081, 0.90909091])

# %%
#plot the data and create a line plot
fig,ax=plt.subplots()
ax.plot(x,x**2);

# %%
#use same data to make scatter plot
fig, ax=plt.subplots()
ax.scatter(x, np.exp(x))

# %%
#another sactter plot
fig,ax=plt.subplots()
ax.scatter(x, np.sin(x));

# %%
# make a plot from dictionary
nut_butter_prices= {"Almond butter":10,
                    "Peanut butter":8,
                    "Cashew butter":12}
fig,ax=plt.subplots()
# ax.bar(x=nut_butter_prices.keys(), y= nut_butter_prices.values())..  bar doesnt take x and y as parameters
#ax.bar(nut_butter_prices.keys(), nut_butter_prices.values()).. this or the next is correct
ax.bar(nut_butter_prices.keys(), height= nut_butter_prices.values())
ax.set(title="Mercy's Nut  Butter Store",
      ylabel="Price($)");

# %%
fig, ax= plt.subplots()
ax.barh(list(nut_butter_prices.keys()), list(nut_butter_prices.values()))
# Out:
# <BarContainer object of 3 artists>

# %%
#make some data for histogram and plot it
x=np.random.randn(1000) #n is for normal distribution
fig,ax=plt.subplots()
ax.hist(x);

# %% [markdown]
# # two options for subplot

# %%
# subplot option 1
fig, ((ax1,ax2), (ax3,ax4))=plt.subplots(nrows=2,
                                         ncols=2,
                                         figsize=(10,5))

# plot to each diff axes
ax1.plot(x,x/2);
ax2.scatter(np.random.random(10), np.random.random(10));
ax3.bar(nut_butter_prices.keys(), nut_butter_prices.values());
ax4.hist(np.random.randn(1000));

# %%
#subplot option 2 uses indexing
fig, ax = plt.subplots(nrows=2,
                       ncols=2,
                       figsize=(10,5))

#plot to each different index
ax[0,0].plot(x,x/2);
ax[0,1].scatter(np.random.random(10), np.random.random(10));
ax[1,0].bar(nut_butter_prices.keys(), nut_butter_prices.values());
ax[1,1].hist(np.random.randn(1000))
# Out:
# (array([ 14.,  34., 130., 224., 268., 174., 107.,  42.,   5.,   2.]),
#  array([-2.90441658, -2.23530592, -1.56619527, -0.89708462, -0.22797396,
#          0.44113669,  1.11024735,  1.779358  ,  2.44846865,  3.11757931,
#          3.78668996]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Plotting from Pandas Dataframe

# %%
import pandas as pd
import numpy as np

# %%
# make a dataframe
car_sales=pd.read_csv("./csv_files/car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
ts = pd.Series(np.random.randn(1000), 
               index=pd.date_range("1/1/2021", periods=1000))

# cumulative sum over a dataframe or series axis
ts = ts.cumsum()

ts.plot()
# Out:
# <AxesSubplot:>

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales["Price"]=car_sales["Price"].str.replace('[\$\,\.]', '')
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
type(car_sales["Price"])
# Out:
# pandas.core.series.Series

# %%
type(car_sales["Price"][0])
# Out:
# str

# %%
#remove last two zeros in carsales rice column
car_sales["Price"]=car_sales["Price"].str[:-2]
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_sales["Sale Date"]=pd.date_range("1/1/2021", periods=len(car_sales))
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date
# 0  Toyota  White         150043      4   4000 2021-01-01
# 1   Honda    Red          87899      4   5000 2021-01-02
# 2  Toyota   Blue          32549      3   7000 2021-01-03
# 3     BMW  Black          11179      5  22000 2021-01-04
# 4  Nissan  White         213095      4   3500 2021-01-05
# 5  Toyota  Green          99213      4   4500 2021-01-06
# 6   Honda   Blue          45698      4   7500 2021-01-07
# 7   Honda   Blue          54738      4   7000 2021-01-08
# 8  Toyota  White          60000      4   6250 2021-01-09
# 9  Nissan  White          31600      4   9700 2021-01-10

# %%
car_sales["Total Sales"] = car_sales["Price"].cumsum()
car_sales
#the output is because price column is in str
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  \
# 0  Toyota  White         150043      4   4000 2021-01-01
# 1   Honda    Red          87899      4   5000 2021-01-02
# 2  Toyota   Blue          32549      3   7000 2021-01-03
# 3     BMW  Black          11179      5  22000 2021-01-04
# 4  Nissan  White         213095      4   3500 2021-01-05
# 5  Toyota  Green          99213      4   4500 2021-01-06
# 6   Honda   Blue          45698      4   7500 2021-01-07
# 7   Honda   Blue          54738      4   7000 2021-01-08
# 8  Toyota  White          60000      4   6250 2021-01-09
# 9  Nissan  White          31600      4   9700 2021-01-10
#
#                                  Total Sales
# 0                                       4000
# 1                                   40005000
# 2                               400050007000
# 3                          40005000700022000
# 4                      400050007000220003500
# 5                  4000500070002200035004500
# ...

# %%
type(car_sales["Price"][0])
# Out:
# str

# %%
car_sales["Total Sales"] = car_sales["Price"].astype(int).cumsum()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Total Sales
# 0  Toyota  White         150043      4   4000         4000
# 1   Honda    Red          87899      4   5000         9000
# 2  Toyota   Blue          32549      3   7000        16000
# 3     BMW  Black          11179      5  22000        38000
# 4  Nissan  White         213095      4   3500        41500
# 5  Toyota  Green          99213      4   4500        46000
# 6   Honda   Blue          45698      4   7500        53500
# 7   Honda   Blue          54738      4   7000        60500
# 8  Toyota  White          60000      4   6250        66750
# 9  Nissan  White          31600      4   9700        76450

# %%
# lets plot the total sales
car_sales.plot(x="Sale Date", y="Total Sales");

# %%
#reasign  price column as int
car_sales["Price"] = car_sales["Price"].astype(int)

#plot scatter plot with price column as numeric
car_sales.plot(x="Odometer (KM)", y="Price", kind="scatter")
# Out:
# <AxesSubplot:xlabel='Odometer (KM)', ylabel='Price'>

# %%
# a bargraph
x=np.random.rand(10,4)
x

#turning into a dataframe
df=pd.DataFrame(x, columns=["a", "b", "c", "d"])
df
# Out:
#           a         b         c         d
# 0  0.807866  0.377569  0.311252  0.730726
# 1  0.287554  0.261819  0.256081  0.002866
# 2  0.121106  0.051604  0.114467  0.011040
# 3  0.430454  0.765796  0.675461  0.843608
# 4  0.813302  0.155710  0.703905  0.545062
# 5  0.352886  0.939229  0.478991  0.518159
# 6  0.089641  0.220084  0.354102  0.731659
# 7  0.975496  0.861190  0.728413  0.271014
# 8  0.388123  0.050161  0.538465  0.921288
# 9  0.662887  0.222582  0.268872  0.155120

# %%
df.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df.plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
# always view ur data as u make visualizations
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Total Sales
# 0  Toyota  White         150043      4   4000         4000
# 1   Honda    Red          87899      4   5000         9000
# 2  Toyota   Blue          32549      3   7000        16000
# 3     BMW  Black          11179      5  22000        38000
# 4  Nissan  White         213095      4   3500        41500
# 5  Toyota  Green          99213      4   4500        46000
# 6   Honda   Blue          45698      4   7500        53500
# 7   Honda   Blue          54738      4   7000        60500
# 8  Toyota  White          60000      4   6250        66750
# 9  Nissan  White          31600      4   9700        76450

# %%
car_sales.plot(x="Make", y="Odometer (KM)", kind="bar")
# Out:
# <AxesSubplot:xlabel='Make'>

# %%
# histograms-- visualize spread of data
car_sales["Odometer (KM)"].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
car_sales["Odometer (KM)"].plot(kind="hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# default bins is 10

car_sales["Odometer (KM)"].plot.hist(bins=20);

# %%
#using the heart disease dataset
heart_disease=pd.read_csv("./csv_files/heart-disease.csv")
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
# create a histogram of age
heart_disease["age"].plot.hist(bins=10);

#outlier is data thtis far from the middle

# %%
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart_disease.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
heart_disease.plot.hist(figsize=(10,30), subplots=True);

# %% [markdown]
# # which should be used(pyplot or matplotlib oo method)
# ## * pyplot can be used for quick plots
# ## * for more advanced plots, we use the oo method

# %%
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
over_50=heart_disease[heart_disease["age"] > 50]
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
# pyplot method(plotting directly with plot)
over_50.plot(kind="scatter",
              x="age",
              y="chol",
              c="target");
# cis color
# Out:
# C:\Users\Isaac Alexander\Anaconda3\lib\site-packages\pandas\plotting\_tools.py:307: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# C:\Users\Isaac Alexander\Anaconda3\lib\site-packages\pandas\plotting\_tools.py:307: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# C:\Users\Isaac Alexander\Anaconda3\lib\site-packages\pandas\plotting\_tools.py:313: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
#oop method mixed with pyplot

fig,ax=plt.subplots(figsize=(10,6))
over_50.plot(kind="scatter",
             x="age",
             y="chol",
             c="target",
             ax=ax)

#figure is the entire image
#ax -axes is where we are ploting data

ax.set_xlim([45,100]) # change limits of x axis
# Out:
# (45.0, 100.0)

# %%
# oo method from scratch
fig, ax=plt.subplots(figsize=(10,6))

#plot the data
scatter=ax.scatter(x=over_50["age"],
                   y=over_50["chol"],
                   c=over_50["target"]) # target has vlues 1 and 0, so it gives it diff colors based on the values

# customize the plot
ax.set(title="Heart Disease and Cholesterol levels",
            xlabel = "Age",
            ylabel="Cholesterol")

#add a legend
ax.legend(*scatter.legend_elements(), title="Target") #* is used to get all the values from scatter and unpack legend elements and query the c parameter and  and give a legend built off the elements

# add a horizontal line
ax.axhline(over_50["chol"].mean(),
          linestyle="--")

# %%
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
# Subplots of chol,age,thalach
fig, (ax0, ax1)=plt.subplots(nrows=2,
                           ncols=1,
                           figsize=(10,10),
                           sharex= True) # since x values are same, then remove xlabel from ax0

#add data to ax0
scatter=ax0.scatter(x=over_50["age"],
                    y=over_50["chol"],
                    c=over_50["target"])

#customize ax0
ax0.set(title="Heart Disease and Cholesterol Levels",
        xlabel="Age",
        ylabel="Cholesterol")

#add a legend to ax0
ax0.legend(*scatter.legend_elements(), title="Target")

#add a meanline
ax0.axhline(y=over_50["chol"].mean(),
            linestyle="--");

#add data to ax1
scattwe=ax1.scatter(x=over_50["age"],
                    y=over_50["thalach"],
                    c= over_50["target"])
#customize ax1
ax1.set(title="Heart Disease and Max Heart Rate",
       ylabel="Max Heart Rate")

# add a legend to ax1
ax1.legend(*scatter.legend_elements(), title="Target")

#add a meanline
ax1.axhline(y=over_50["thalach"].mean(),
            linestyle="--");

# add a title to entire figure
fig.suptitle("Heart Disease Analysis", fontsize=16, fontweight="bold")
# Out:
# Text(0.5, 0.98, 'Heart Disease Analysis')

# %% [markdown]
# ## Customization in matplotlib

# %%
# diff styles available
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2021-01-01         4000
# 1   Honda    Red          87899      4   5000 2021-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2021-01-03        16000
# 3     BMW  Black          11179      5  22000 2021-01-04        38000
# 4  Nissan  White         213095      4   3500 2021-01-05        41500
# 5  Toyota  Green          99213      4   4500 2021-01-06        46000
# 6   Honda   Blue          45698      4   7500 2021-01-07        53500
# 7   Honda   Blue          54738      4   7000 2021-01-08        60500
# 8  Toyota  White          60000      4   6250 2021-01-09        66750
# 9  Nissan  White          31600      4   9700 2021-01-10        76450

# %%
car_sales["Price"].plot();

# %%
plt.style.use("seaborn-whitegrid")

# %%
car_sales["Price"].plot()
# Out:
# <AxesSubplot:>

# %%
plt.style.use("seaborn")

# %%
car_sales["Price"].plot()
# Out:
# <AxesSubplot:>

# %%
car_sales.plot(x="Odometer (KM)", y="Price", kind="scatter")
# Out:
# <AxesSubplot:xlabel='Odometer (KM)', ylabel='Price'>

# %%
plt.style.use("ggplot")
car_sales["Price"].plot();

# %%
# create some data
x=np.random.randn(10,4)
x
# Out:
# array([[ 0.40303772,  1.7507022 , -1.02650858,  1.0544927 ],
#        [ 0.86999638, -0.33390153, -0.73269606, -0.49317978],
#        [-0.91206336,  1.13801317,  0.97898314, -0.1334182 ],
#        [-0.22609557, -0.3690524 , -0.19805063, -0.61881701],
#        [-0.67830613,  2.55316629,  0.31133232, -0.26231728],
#        [ 0.13633861, -0.87633688, -0.93972798, -0.36615076],
#        [ 1.37468805, -0.26582424, -0.25534762, -0.33086136],
#        [ 1.00311841, -0.25891325, -2.62790076, -2.81942009],
#        [-0.27990909,  0.21776004,  0.80511702,  0.46024019],
#        [ 0.40478587, -0.35203567, -0.7496041 ,  0.95458434]])

# %%
df=pd.DataFrame(x, columns=["a","b","c","d"])
df
# Out:
#           a         b         c         d
# 0  0.403038  1.750702 -1.026509  1.054493
# 1  0.869996 -0.333902 -0.732696 -0.493180
# 2 -0.912063  1.138013  0.978983 -0.133418
# 3 -0.226096 -0.369052 -0.198051 -0.618817
# 4 -0.678306  2.553166  0.311332 -0.262317
# 5  0.136339 -0.876337 -0.939728 -0.366151
# 6  1.374688 -0.265824 -0.255348 -0.330861
# 7  1.003118 -0.258913 -2.627901 -2.819420
# 8 -0.279909  0.217760  0.805117  0.460240
# 9  0.404786 -0.352036 -0.749604  0.954584

# %%
ax=df.plot(kind="bar")
type(ax)
# Out:
# matplotlib.axes._subplots.AxesSubplot

# %%
#customize our plot using set method
ax=df.plot(kind="bar")
#add some labels and a title
ax.set(title="Random Number Bar Graph from DataFrame",
       xlabel="Row Number",
       ylabel="Random Number")

# make the legend visible
ax.legend().set_visible(True)

# %%
# set the style
plt.style.use("seaborn-whitegrid")

fig, ax=plt.subplots(figsize=(10,6))

#plot the data
scatter=ax.scatter(x=over_50["age"],
                   y=over_50["chol"],
                   c=over_50["target"], # target has vlues 1 and 0, so it gives it diff colors based on the values
                   cmap="viridis") # this changes color scheme, look at matplotlib color documentation

# customize the plot
ax.set(title="Heart Disease and Cholesterol levels",
            xlabel = "Age",
            ylabel="Cholesterol")

#add a legend
ax.legend(*scatter.legend_elements(), title="Target") #* is used to get all the values from scatter and unpack legend elements and query the c parameter and  and give a legend built off the elements

# add a horizontal line
ax.axhline(over_50["chol"].mean(),
          linestyle="--")

# %% [markdown]
# ## this plot shows info about the heart disease dataset

# %%
## Customizing the y and x axis limitations
# Subplots of chol,age,thalach
fig, (ax0, ax1)=plt.subplots(nrows=2,
                           ncols=1,
                           figsize=(10,10),
                           sharex= True) # since x values are same, then remove xlabel from ax0

#add data to ax0
scatter=ax0.scatter(x=over_50["age"],
                    y=over_50["chol"],
                    c=over_50["target"],
                    cmap="winter")

#customize ax0
ax0.set(title="Heart Disease and Cholesterol Levels",
        xlabel="Age",
    ylabel="Cholesterol")

# change x axis limit
ax0.set_xlim([50,80])



#add a legend to ax0
ax0.legend(*scatter.legend_elements(), title="Target")

#add a meanline
ax0.axhline(y=over_50["chol"].mean(),
            linestyle="--");

#add data to ax1
scattwe=ax1.scatter(x=over_50["age"],
                    y=over_50["thalach"],
                    c= over_50["target"],
                    cmap="summer")
#customize ax1
ax1.set(title="Heart Disease and Max Heart Rate",
       ylabel="Max Heart Rate")

# change ax1 x axis limit
ax1.set_xlim([50,80])
ax1.set_ylim([60,200])


# add a legend to ax1
ax1.legend(*scatter.legend_elements(), title="Target")

#add a meanline
ax1.axhline(y=over_50["thalach"].mean(),
            linestyle="--");

# add a title to entire figure
fig.suptitle("Heart Disease Analysis", fontsize=16, fontweight="bold")
# Out:
# Text(0.5, 0.98, 'Heart Disease Analysis')

# %% [markdown]
# ## u can save by right clicking on the image or with code as below

# %%
fig.savefig("heart-disease-analysis-plot-saved-with-code.png")
